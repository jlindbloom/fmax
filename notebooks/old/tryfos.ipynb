# %%
import pymc3 as pm
import pandas as pd
import matplotlib.pyplot as plt
import fmax as fm
import numpy as np

# %%
def plot_posterior_predictive(fcast_model, test_data, label, actual):
    """Simple plot of the posterior predictive of a forecast model.
    """

    sample_paths = fcast_model.ppc['running_max']
    index = fcast_model.master_with_fcast_index

    # Calculate the 1%, 10%, 50%, 90%, and 99% quantiles
    lower_bound_one = np.quantile(sample_paths, q=0.01, axis=0)
    lower_bound_ten = np.quantile(sample_paths, q=0.1, axis=0)
    medians = np.quantile(sample_paths, q=0.5, axis=0)
    upper_bound_ninety = np.quantile(sample_paths, q=0.9, axis=0)
    upper_bound_ninety_nine = np.quantile(sample_paths, q=0.99, axis=0)

    # Plot
    fig, axs = plt.subplots(figsize=(13,8))

    # Plot sample paths on the left
    # axs[0].plot(index, sample_paths[:10000,:].T, alpha=0.05)
    # axs[0].plot(fcast_model.train_index, fcast_model.train_data, color="red", label="Training")
    # axs[0].plot(fcast_model.fcast_index, test_data, color="black", label="Testing")
    # axs[0].legend()
    # axs[0].set_xlabel("Period")
    # axs[0].set_ylabel("Record")
    # axs[0].set_title("Many Posterior Predictive Sample Paths")


    # Plot CI on the right
    axs.fill_between(index, lower_bound_one, upper_bound_ninety_nine, alpha=0.4, label="99% CI", color="C0")
    axs.fill_between(index, lower_bound_ten, upper_bound_ninety, alpha=0.7, label="80% CI", color="C0")
    axs.plot(index, medians, label="Median")
    axs.plot(fcast_model.train_index, fcast_model.train_data, color="red", label="Training")
    axs.plot(fcast_model.fcast_index, test_data, color="black", label="Tryfos")
    axs.plot(fcast_model.fcast_index, actual, color="green", label="Actual")
    axs.legend()
    axs.set_xlabel("Period")
    axs.set_ylabel("Record")
    axs.set_title(label)

    fig.tight_layout()

    return fig

# %% [markdown]
# # Gaussian

# %%
whiches = ["1000m", "1m", "5000m", "Marathon"]
for which in whiches:
    df = pd.read_csv("tryfos_data.csv")
    years, records = df["Year"].values, df[which].values # Years 1983 and onward are just forecasts

    training_years = years[:15]
    training_records = records[:15]
    tryfos_years = years[15:]
    tryfos_fcast = records[15:]

    model = fm.ForecastModel(training_records, kind="min", train='all', fcast_len=len(tryfos_fcast))
    model.fit(attempts_mean_mu=training_records[0], attempts_mean_sigma=0.05*training_records[0], attempts_stdev_lam=1, chains=3, draws=40000, tune=20000)

    model.draw_forecasts()

    actual_df = pd.read_csv("tryfos_actual.csv")
    _, actual_records = actual_df["Year"].values, actual_df[which].values

    fig = plot_posterior_predictive(model, tryfos_fcast, f"{which}, Gaussian Attempts", actual_records)
    fig.savefig(f"{which}_gaussian_attempts.png")
# Out:
# WARNING (theano.tensor.opt): Optimization Warning: The Op erfcx does not provide a C implementation. As well as being potentially slow, this also disables loop fusion.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (3 chains in 1 job)
# NUTS: [sigma, mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:24<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:23<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:15<00:00 Sampling chain 2, 0 divergences]
#     </div>
# Sampling 3 chains for 20_000 tune and 40_000 draw iterations (60_000 + 120_000 draws total) took 243 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='120000' class='' max='120000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [120000/120000 00:35<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (3 chains in 1 job)
# NUTS: [sigma, mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:23<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:20<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:26<00:00 Sampling chain 2, 0 divergences]
#     </div>
# Sampling 3 chains for 20_000 tune and 40_000 draw iterations (60_000 + 120_000 draws total) took 251 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='120000' class='' max='120000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [120000/120000 00:36<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (3 chains in 1 job)
# NUTS: [sigma, mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:14<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:15<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:16<00:00 Sampling chain 2, 0 divergences]
#     </div>
# Sampling 3 chains for 20_000 tune and 40_000 draw iterations (60_000 + 120_000 draws total) took 227 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='120000' class='' max='120000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [120000/120000 00:35<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (3 chains in 1 job)
# NUTS: [sigma, mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:05<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:19<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:16<00:00 Sampling chain 2, 0 divergences]
#     </div>
# Sampling 3 chains for 20_000 tune and 40_000 draw iterations (60_000 + 120_000 draws total) took 221 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='120000' class='' max='120000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [120000/120000 00:36<00:00]
#     </div>

# %% [markdown]
# # Gumbel

# %%
whiches = ["1000m", "1m", "5000m", "Marathon"]
#whiches = ["1000m"]
for which in whiches:
    df = pd.read_csv("tryfos_data.csv")
    years, records = df["Year"].values, df[which].values # Years 1983 and onward are just forecasts

    training_years = years[:15]
    training_records = records[:15]
    tryfos_years = years[15:]
    tryfos_fcast = records[15:]

    model = fm.ForecastModel(training_records, kind="min", train='all', fcast_len=len(tryfos_fcast), attempts="gumbel")
    model.fit(attempts_mean_mu=-training_records[0], attempts_mean_sigma=0.05*training_records[0], attempts_stdev_lam=1, chains=1, draws=40000, tune=20000)

    model.draw_forecasts()

    actual_df = pd.read_csv("tryfos_actual.csv")
    _, actual_records = actual_df["Year"].values, actual_df[which].values

    fig = plot_posterior_predictive(model, tryfos_fcast, f"{which}, Gumbel Attempts", actual_records)
    fig.savefig(f"{which}_gumbel_attempts.png")
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [sigma, mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:19<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 20_000 tune and 40_000 draw iterations (20_000 + 40_000 draws total) took 80 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 00:12<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [sigma, mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:12<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 20_000 tune and 40_000 draw iterations (20_000 + 40_000 draws total) took 73 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 00:12<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [sigma, mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 01:21<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 20_000 tune and 40_000 draw iterations (20_000 + 40_000 draws total) took 81 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 00:12<00:00]
#     </div>
# ---------------------------------------------------------------------------
# SamplingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_114168/3515256800.py in <module>
#      11
#      12     model = fm.ForecastModel(training_records, kind="min", train='all', fcast_len=len(tryfos_fcast), attempts="gumbel")
# ---> 13     model.fit(attempts_mean_mu=-training_records[0], attempts_mean_sigma=0.05*training_records[0], attempts_stdev_lam=1, chains=1, draws=40000, tune=20000)
#      14
#      15     model.draw_forecasts()
#
# c:\users\jonathan\github\fmax\fmax\models\models.py in fit(self, attempts_mean_mu, attempts_mean_sigma, attempts_stdev_lam, chains, draws, tune)
#      91         with self.pymc_model:
#      92
# ---> 93             self.trace = pm.sample(draws=draws, chains=chains, tune=tune, cores=1, target_accept=0.99,
#      94                     return_inferencedata=True,
#      95                     idata_kwargs={"density_dist_obs": False})
#
# ~\miniconda3\envs\pm3env\lib\site-packages\pymc3\sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, pickle_backend, **kwargs)
#     426     start = deepcopy(start)
#     427     if start is None:
# --> 428         check_start_vals(model.test_point, model)
#     429     else:
#     430         if isinstance(start, dict):
#
# ~\miniconda3\envs\pm3env\lib\site-packages\pymc3\util.py in check_start_vals(start, model)
#     235
#     236         if not np.all(np.isfinite(initial_eval)):
# --> 237             raise SamplingError(
#     238                 "Initial evaluation of model at starting point failed!\n"
#     239                 "Starting values:\n{}\n\n"
#
# SamplingError: Initial evaluation of model at starting point failed!
# Starting values:
# {'mu': array(-7777.), 'sigma_log__': array(-0.36651292)}
#
# Initial evaluation results:
# mu            -6.88
# sigma_log__   -1.06
# running_max    -inf
# Name: Log-probability of test_point, dtype: float64

# %%
whiches = ["Marathon"]
#whiches = ["1000m"]
for which in whiches:
    df = pd.read_csv("tryfos_data.csv")
    years, records = df["Year"].values, df[which].values # Years 1983 and onward are just forecasts

    training_years = years[:15]
    training_records = records[:15]
    tryfos_years = years[15:]
    tryfos_fcast = records[15:]

    model = fm.ForecastModel(training_records, kind="min", train='all', fcast_len=len(tryfos_fcast), attempts="gumbel")
    model.fit(attempts_mean_mu=-training_records[0], attempts_mean_sigma=0.05*training_records[0], attempts_stdev_lam=1, chains=1, draws=40000, tune=20000)

    model.draw_forecasts()

    actual_df = pd.read_csv("tryfos_actual.csv")
    _, actual_records = actual_df["Year"].values, actual_df[which].values

    fig = plot_posterior_predictive(model, tryfos_fcast, f"{which}, Gumbel Attempts", actual_records)
    fig.savefig(f"{which}_gumbel_attempts.png")
# Out:
# ---------------------------------------------------------------------------
# SamplingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_114168/3595072359.py in <module>
#      11
#      12     model = fm.ForecastModel(training_records, kind="min", train='all', fcast_len=len(tryfos_fcast), attempts="gumbel")
# ---> 13     model.fit(attempts_mean_mu=-training_records[0], attempts_mean_sigma=0.05*training_records[0], attempts_stdev_lam=1, chains=1, draws=40000, tune=20000)
#      14
#      15     model.draw_forecasts()
#
# c:\users\jonathan\github\fmax\fmax\models\models.py in fit(self, attempts_mean_mu, attempts_mean_sigma, attempts_stdev_lam, chains, draws, tune)
#      91         with self.pymc_model:
#      92
# ---> 93             self.trace = pm.sample(draws=draws, chains=chains, tune=tune, cores=1, target_accept=0.99,
#      94                     return_inferencedata=True,
#      95                     idata_kwargs={"density_dist_obs": False})
#
# ~\miniconda3\envs\pm3env\lib\site-packages\pymc3\sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, pickle_backend, **kwargs)
#     426     start = deepcopy(start)
#     427     if start is None:
# --> 428         check_start_vals(model.test_point, model)
#     429     else:
#     430         if isinstance(start, dict):
#
# ~\miniconda3\envs\pm3env\lib\site-packages\pymc3\util.py in check_start_vals(start, model)
#     235
#     236         if not np.all(np.isfinite(initial_eval)):
# --> 237             raise SamplingError(
#     238                 "Initial evaluation of model at starting point failed!\n"
#     239                 "Starting values:\n{}\n\n"
#
# SamplingError: Initial evaluation of model at starting point failed!
# Starting values:
# {'mu': array(-7777.), 'sigma_log__': array(-0.36651292)}
#
# Initial evaluation results:
# mu            -6.88
# sigma_log__   -1.06
# running_max    -inf
# Name: Log-probability of test_point, dtype: float64

# %%
plt.plot(records)

# %%
def gumbel_attempts_min(jump_data, flat_data, mu, sigma):
    """Log likelihood with a Gumbel attempt distribution.
    """

    beta = (1/np.pi)*pm.math.sqrt(6)*sigma
    #pm.math.sqrt((6/(np.pi**2))*(sigma**2))
    mu = mu - beta*np.euler_gamma

    x_dist = pm.Gumbel.dist(mu=mu, beta=beta)
    
    # Add likelihood contribution from the jump data
    log_likelihood = pm.math.sum(x_dist.logp(-jump_data))

    # Contribution from the flat data
    #log_likelihood += pm.math.sum(pm.math.log1mexp(x_dist.logcdf(-flat_data)))

    log_likelihood

    return log_likelihood

# %%
gumbel_attempts_min([0.2, 0.4], [0.2, 0.4] )

# %%
mu = 1
sigma = 10

beta = (1/np.pi)*pm.math.sqrt(6)*sigma
    #pm.math.sqrt((6/(np.pi**2))*(sigma**2))
mu = mu - beta*np.euler_gamma

x_dist = pm.Gumbel.dist(mu=mu, beta=beta)

# %%
x_dist.logp(-np.array([0.1, 0.1])).eval()
# Out:
# array([-3.13640048, -3.13640048])

# %%
pm.math.log1mexp(x_dist.logcdf(np.array([1, 1]))).eval()
# Out:
# array([nan, nan])

# %%
np.log(1 - np.exp(x_dist.logcdf(-np.array([0.1, 0.1])).eval()))
# Out:
# array([-0.74204389, -0.74204389])
